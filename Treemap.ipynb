# %% [markdown]
# # Gráfico do tipo Treemap

# %%
# libraries
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import squarify    # pip install squarify (algorithm for treemap)

# %%
# If you have 2 lists
squarify.plot(sizes=[73,65,65,65,56,52,45,44,27,26,25,19,19,15,14,8,5,4,3,3,3,2,1], label=["mTERF", "PHD", "SET", "SNF2", "GNAT", "Others", "AUX/IAA", "Jumonji", "TRAF", "LUG", "SWI/SNF-BAF60b", "ARID", "IWS1", "Pseudo", "HMG", "MED6", "TAZ", "MBF1", "Coactivator", "MED7", "RB", "Rcd1", "SOH1"], alpha=.7)
plt.axis('off')
plt.title('Abundância das Famílias CoREG')
plt.show() #junta vários gráficos em um
plt.rcParams['figure.figsize'] = (18,9)
plt.savefig('Tremap.svg')
